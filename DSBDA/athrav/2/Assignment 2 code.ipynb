# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("StudentPerformance1.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=pd.read_csv("StudentPerformance1.csv")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df=pd.read_csv("StudentsPerformanceTest1.csv")

# %%
df
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0  female         72            72           74.0             78.0
# 1  female         69            90           88.0              NaN
# 2  female         90            95           93.0             74.0
# 3    male         47            57            NaN             78.0
# 4    male         na            78           75.0             81.0
# 5  female         71            Na           78.0             70.0
# 6    male         12            44           52.0             12.0
# 7    male        NaN            65           67.0             49.0
# 8    male          5            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# ...

# %%
df.isnull()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0   False       False          False          False            False
# 1   False       False          False          False             True
# 2   False       False          False          False            False
# 3   False       False          False           True            False
# 4   False       False          False          False            False
# 5   False       False          False          False            False
# 6   False       False          False          False            False
# 7   False        True          False          False            False
# 8   False       False          False          False            False
#
#    placement offer count  Region
# 0                  False   False
# 1                  False   False
# 2                  False   False
# 3                  False   False
# 4                  False   False
# 5                  False   False
# 6                  False   False
# ...

# %%
series=pd.isnull(df["math score"])
 df[series]
# Out:
#   Cell In[7], line 2
#     df[series]
#     ^
# IndentationError: unexpected indent

# %%
series=pd.isnull(df["math score"])
df[series]
# Out:
#   gender math score reading score  writing score  Placement Score  \
# 7   male        NaN            65           67.0             49.0
#
#    placement offer count Region
# 7                      1   Pune

# %%
import pandas as pd
import numpy as np

# %%
df.notnull()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0    True        True           True           True             True
# 1    True        True           True           True            False
# 2    True        True           True           True             True
# 3    True        True           True          False             True
# 4    True        True           True           True             True
# 5    True        True           True           True             True
# 6    True        True           True           True             True
# 7    True       False           True           True             True
# 8    True        True           True           True             True
#
#    placement offer count  Region
# 0                   True    True
# 1                   True    True
# 2                   True    True
# 3                   True    True
# 4                   True    True
# 5                   True    True
# 6                   True    True
# ...

# %%
series=pd.notnull(df["math score"])
df[series]
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0  female         72            72           74.0             78.0
# 1  female         69            90           88.0              NaN
# 2  female         90            95           93.0             74.0
# 3    male         47            57            NaN             78.0
# 4    male         na            78           75.0             81.0
# 5  female         71            Na           78.0             70.0
# 6    male         12            44           52.0             12.0
# 8    male          5            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# 8                      0     NaN

# %%
from sklearn.preprocessing import LabelEncoder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from sklearn.preprocessing import LabelEncoder
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.1 MB 1.6 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/11.1 MB 1.8 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/11.1 MB 1.9 MB/s eta 0:00:06
#    ------- -------------------------------- 2.1/11.1 MB 2.0 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/11.1 MB 2.1 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/11.1 MB 2.0 MB/s eta 0:00:05
#    ------------- -------------------------- 3.7/11.1 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.2/11.1 MB 2.3 MB/s eta 0:00:04
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['gender']=le.fit_transform(df['gender'])

# %%
newdf=df
df
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0       0         72            72           74.0             78.0
# 1       0         69            90           88.0              NaN
# 2       0         90            95           93.0             74.0
# 3       1         47            57            NaN             78.0
# 4       1         na            78           75.0             81.0
# 5       0         71            Na           78.0             70.0
# 6       1         12            44           52.0             12.0
# 7       1        NaN            65           67.0             49.0
# 8       1          5            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# ...

# %%
missing_values=["Na","na"]
df=pd.read_csv("/home/jaihind/Desktop/StudentPerformance.csv",na_values=mis
# Out:
#   Cell In[18], line 2
#     df=pd.read_csv("/home/jaihind/Desktop/StudentPerformance.csv",na_values=mis
#                                                                                ^
# _IncompleteInputError: incomplete input

# %%
missing_values=["Na","na"]
df=pd.read_csv("StudentPerformance1.csv",na_values=mis
# Out:
#   Cell In[19], line 2
#     df=pd.read_csv("StudentPerformance1.csv",na_values=mis
#                                                           ^
# _IncompleteInputError: incomplete input

# %%
df = pd.read_csv("StudentPerformance1.csv", na_values=missing_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df = pd.read_csv("StudentPerformance1.csv", na_values=missing_values)
#
# NameError: name 'missing_values' is not defined

# %%
missing_values=["Na","na"]
df = pd.read_csv("StudentsPerformanceTest1.csv", na_values=missing_values)

# %%
df
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female        72.0           72.0           74.0             78.0
# 1  female        69.0           90.0           88.0              NaN
# 2  female        90.0           95.0           93.0             74.0
# 3    male        47.0           57.0            NaN             78.0
# 4    male         NaN           78.0           75.0             81.0
# 5  female        71.0            NaN           78.0             70.0
# 6    male        12.0           44.0           52.0             12.0
# 7    male         NaN           65.0           67.0             49.0
# 8    male         5.0           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
ndf=df

# %%
ndf.fillna(0)
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female        72.0           72.0           74.0             78.0
# 1  female        69.0           90.0           88.0              0.0
# 2  female        90.0           95.0           93.0             74.0
# 3    male        47.0           57.0            0.0             78.0
# 4    male         0.0           78.0           75.0             81.0
# 5  female        71.0            0.0           78.0             70.0
# 6    male        12.0           44.0           52.0             12.0
# 7    male         0.0           65.0           67.0             49.0
# 8    male         5.0           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2       0
# 2                      2  Nashik
# 3                      1       0
# 4                      3    Pune
# 5                      4       0
# 6                      2  Nashik
# ...

# %%
m_v=df['math score'].mean()

# %%
df['math score'].fillna(value=m_v, inplace=True)
# Out:
# C:\Users\satej\AppData\Local\Temp\ipykernel_8172\1160731484.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['math score'].fillna(value=m_v, inplace=True)

# %%
df['math score'] = df['math score'].fillna(value=m_v)

# %%
df
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 1  female   69.000000           90.0           88.0              NaN
# 2  female   90.000000           95.0           93.0             74.0
# 3    male   47.000000           57.0            NaN             78.0
# 4    male   52.285714           78.0           75.0             81.0
# 5  female   71.000000            NaN           78.0             70.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
# 8    male    5.000000           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
ndf.replace(to_replace=np.nan,value=-99)
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 1  female   69.000000           90.0           88.0            -99.0
# 2  female   90.000000           95.0           93.0             74.0
# 3    male   47.000000           57.0          -99.0             78.0
# 4    male   52.285714           78.0           75.0             81.0
# 5  female   71.000000          -99.0           78.0             70.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
# 8    male    5.000000           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     -99
# 2                      2  Nashik
# 3                      1     -99
# 4                      3    Pune
# 5                      4     -99
# 6                      2  Nashik
# ...

# %%
ndf.dropna()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 2  female   90.000000           95.0           93.0             74.0
# 4    male   52.285714           78.0           75.0             81.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
#
#    placement offer count  Region
# 0                      1    Pune
# 2                      2  Nashik
# 4                      3    Pune
# 6                      2  Nashik
# 7                      1    Pune

# %%
ndf.dropna(how='all')
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 1  female   69.000000           90.0           88.0              NaN
# 2  female   90.000000           95.0           93.0             74.0
# 3    male   47.000000           57.0            NaN             78.0
# 4    male   52.285714           78.0           75.0             81.0
# 5  female   71.000000            NaN           78.0             70.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
# 8    male    5.000000           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
ndf.dropna(axis=1)
# Out:
#    gender  math score  placement offer count
# 0  female   72.000000                      1
# 1  female   69.000000                      2
# 2  female   90.000000                      2
# 3    male   47.000000                      1
# 4    male   52.285714                      3
# 5  female   71.000000                      4
# 6    male   12.000000                      2
# 7    male   52.285714                      1
# 8    male    5.000000                      0

# %%
new_data=ndf.dropna(axis=0, how='any')

# %%
new_data
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 2  female   90.000000           95.0           93.0             74.0
# 4    male   52.285714           78.0           75.0             81.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
#
#    placement offer count  Region
# 0                      1    Pune
# 2                      2  Nashik
# 4                      3    Pune
# 6                      2  Nashik
# 7                      1    Pune

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("demo1(1).csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df=pd.read_csv("demo1(1).csv")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df=pd.read_csv("demo1.csv")

# %%
df
# Out:
#     math score  reading score  writing score  placement score  \
# 0           80             68             70               89
# 1           71             61             85               91
# 2           79             16             87               77
# 3           61             77             74               76
# 4           78             71             67               90
# 5           73             68             90               80
# 6           77             62             70               35
# 7           74             45             80               12
# 8           76             60             79               77
# 9           75             65             85               87
# 10         160             67             12               83
# 11          79             72             88              180
# 12          80             80             78               94
# 13          78             69             71               90
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib --no-cache-dir
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 4.2 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.1 MB 6.1 MB/s eta 0:00:01
#    -------------- ------------------------- 2.9/8.1 MB 5.9 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.1 MB 4.5 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 5.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 4.9 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.1 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 4.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
# ...

# %%
import matplotlib.pyplot as plt

# %%
col=['math score','reading score','writing score','placement score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
 print(np.where(df['math score']>90))
# Out:
# (array([10, 21, 25, 28]),)

# %%
print(np.where(df['reading score']<25))
# Out:
# (array([ 2, 14]),)

# %%
print(np.where(df['writing score']<30))
# Out:
# (array([10, 17]),)

# %%
fig,ax=plt.subplots(figsize=(18,10))
ax.scatter(df['placement score'],df['placement offer count'])
plt.show()

# %%
ax.set_ylabel('(Proportion non-retail busines acres)/(town)')
# Out:
# Text(4.444444444444452, 0.5, '(Proportion non-retail busines acres)/(town)')

# %%
ax.set_ylabel('(Full-value property-tax rate)/($10,000)')
# Out:
# Text(4.444444444444452, 0.5, '(Full-value property-tax rate)/($10,000)')

# %%
print(np.where((df['placement score']<50) & (df['placement offer count']>1)))
# Out:
# (array([6]),)

# %%
print(np.where((df['placement score']>85) & (df['placement offer count']<3)))
# Out:
# (array([11]),)

# %%
from scipy import stats

# %%
z=np.abs(stats.zscore(df['math score']))

# %%
print(z)
# Out:
# [0.17564553 0.5282877  0.21482799 0.92011234 0.25401045 0.44992277
#  0.29319292 0.41074031 0.33237538 0.37155785 2.95895157 0.21482799
#  0.17564553 0.25401045 0.37155785 0.25401045 0.05944926 0.17564553
#  0.37155785 0.0972806  0.60665263 0.60800375 0.48910524 0.41074031
#  0.37155785 3.74260085 0.48910524 0.5282877  1.39165302]

# %%
threshold=0.18

# %%
sample_outliers=np.where(z<threshold)

# %%
sample_outliers
# Out:
# (array([ 0, 12, 16, 17, 19]),)

# %%
sorted_rscore=sorted(df['reading score'])

# %%
sorted_rscore
# Out:
# [1,
#  16,
#  45,
#  60,
#  60,
#  61,
#  62,
#  62,
#  62,
#  65,
#  65,
#  65,
#  67,
#  67,
#  68,
#  68,
#  69,
#  70,
#  71,
#  72,
#  73,
#  74,
#  77,
#  77,
#  77,
#  78,
#  79,
#  80,
#  120]

# %%
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 62.0 74.0

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 44.0 92.0

# %%
r_outliers = []
for i in sorted_rscore:
    if (i<lwr_bound or i>upr_bound):
        r_outliers.append(i)
print(r_outliers)
# Out:
# [1, 16, 120]

# %%
new_df=df

# %%
for i in sample_outliers:
    new_df.drop(i,inplace=True)
new_df
# Out:
#     math score  reading score  writing score  placement score  \
# 1           71             61             85               91
# 2           79             16             87               77
# 3           61             77             74               76
# 4           78             71             67               90
# 5           73             68             90               80
# 6           77             62             70               35
# 7           74             45             80               12
# 8           76             60             79               77
# 9           75             65             85               87
# 10         160             67             12               83
# 11          79             72             88              180
# 13          78             69             71               90
# 14          75              1             71               81
# 15          78             62             79               93
# ...

# %%
df=pd.read_csv("/home/jaihind/Downloads/demo1(1).csv")
df_stud=df
ninetieth_percentile = np.percentile(df_stud['math score'], 90)
b = np.where(df_stud['math score']>ninetieth_percentile,
ninetieth_percentile, df_stud['math score'])
print("New array:",b)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df=pd.read_csv("/home/jaihind/Downloads/demo1(1).csv")
#       2 df_stud=df
#       3 ninetieth_percentile = np.percentile(df_stud['math score'], 90)
#
# ...

# %%
df=pd.read_csv("demo1.csv")
df_stud=df
ninetieth_percentile = np.percentile(df_stud['math score'], 90)
b = np.where(df_stud['math score']>ninetieth_percentile,
ninetieth_percentile, df_stud['math score'])
print("New array:",b)
# Out:
# New array: [ 80.  71.  79.  61.  78.  73.  77.  74.  76.  75. 104.  79.  80.  78.
#   75.  78.  86.  80.  75.  82.  69. 100.  72.  74.  75. 104.  72.  71.
#  104.]

# %%
df_stud.insert(1,"m score",b,True)
df_stud
# Out:
#     math score  m score  reading score  writing score  placement score  \
# 0           80     80.0             68             70               89
# 1           71     71.0             61             85               91
# 2           79     79.0             16             87               77
# 3           61     61.0             77             74               76
# 4           78     78.0             71             67               90
# 5           73     73.0             68             90               80
# 6           77     77.0             62             70               35
# 7           74     74.0             45             80               12
# 8           76     76.0             60             79               77
# 9           75     75.0             65             85               87
# 10         160    104.0             67             12               83
# 11          79     79.0             72             88              180
# ...

# %%
import matplotlib.pyplot as plt

# Ensure 'df' is your DataFrame and has a column named 'reading score'
col = ['reading score']  # Column to plot (as a list)

# Create the boxplot
df.boxplot(column=col)  # Use 'column' (singular) for single-column selection
plt.show()  # Display the plot

# %%
median=np.median(sorted_rscore)
median
# Out:
# np.float64(68.0)

# %%
refined_df=df
refined_df['reading score']=np.where(refined_df['reading score']>upr_bound,median
refined_df
# Out:
#   Cell In[89], line 2
#     refined_df['reading score']=np.where(refined_df['reading score']>upr_bound,median
#                                         ^
# SyntaxError: '(' was never closed

# %%
import numpy as np

# Calculate the median (fixing the typo)
median = np.median(df['reading score'])

# Define upper bound (ensure 'upp_bound' is defined, e.g., using IQR)
upp_bound = 100  # Example threshold (replace with your actual value)

# Replace values above 'upp_bound' with the median
refined_df = df.copy()  # Avoid modifying the original DataFrame directly
refined_df['reading score'] = np.where(
    refined_df['reading score'] > upp_bound,
    median,  # Replace outliers with median
    refined_df['reading score']  # Keep original values otherwise
)

refined_df  # Display the result
# Out:
#     math score  m score  reading score  writing score  placement score  \
# 0           80     80.0           68.0             70               89
# 1           71     71.0           61.0             85               91
# 2           79     79.0           16.0             87               77
# 3           61     61.0           77.0             74               76
# 4           78     78.0           71.0             67               90
# 5           73     73.0           68.0             90               80
# 6           77     77.0           62.0             70               35
# 7           74     74.0           45.0             80               12
# 8           76     76.0           60.0             79               77
# 9           75     75.0           65.0             85               87
# 10         160    104.0           67.0             12               83
# 11          79     79.0           72.0             88              180
# ...

# %%
refined_df['reading score']=np.where(refined_df['reading score']<lwr_bound,median
refined_df
# Out:
#   Cell In[91], line 1
#     refined_df['reading score']=np.where(refined_df['reading score']<lwr_bound,median
#                                         ^
# SyntaxError: '(' was never closed

# %%
refined_df['reading score'] = np.where(refined_df['reading score'] < lwr_bound, median, refined_df['reading score'])
refined_df
# Out:
#     math score  m score  reading score  writing score  placement score  \
# 0           80     80.0           68.0             70               89
# 1           71     71.0           61.0             85               91
# 2           79     79.0           68.0             87               77
# 3           61     61.0           77.0             74               76
# 4           78     78.0           71.0             67               90
# 5           73     73.0           68.0             90               80
# 6           77     77.0           62.0             70               35
# 7           74     74.0           45.0             80               12
# 8           76     76.0           60.0             79               77
# 9           75     75.0           65.0             85               87
# 10         160    104.0           67.0             12               83
# 11          79     79.0           72.0             88              180
# ...

# %%
import matplotlib.pyplot as plt  # Make sure this is imported

col = ['reading score']
refined_df.boxplot(column=col)
plt.show()  # This will display the boxplot

# %%
import pandas as pd
 import numpy as np
 df=pd.read_csv("demo1.csv")
# Out:
#   Cell In[95], line 2
#     import numpy as np
#     ^
# IndentationError: unexpected indent

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("demo1.csv")

# %%
df
# Out:
#     math score  reading score  writing score  placement score  \
# 0           80             68             70               89
# 1           71             61             85               91
# 2           79             16             87               77
# 3           61             77             74               76
# 4           78             71             67               90
# 5           73             68             90               80
# 6           77             62             70               35
# 7           74             45             80               12
# 8           76             60             79               77
# 9           75             65             85               87
# 10         160             67             12               83
# 11          79             72             88              180
# 12          80             80             78               94
# 13          78             69             71               90
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

new_df['math score'].plot(kind='hist')
df['log_math'] = np.log10(df['math score'])
df['log_math'].plot(kind='hist')

plt.show()
